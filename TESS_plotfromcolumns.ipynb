# %%
import astropy
from astropy.io import fits 
from pathlib import Path
import matplotlib.pyplot as plt
from astropy.visualization import astropy_mpl_style
plt.style.use(astropy_mpl_style)
from astropy.table import Table
import lightkurve as lk

# %%
#Open 1st file
file = '/Users/katborski/Documents/GitHub/AFPSC/TESS/tess2021232031932-s0042-0000000250081915-0213-a_fast-lc.fits'
data1 = astropy.io.fits.open(file)

# %%
data1.info()
# Out:
# Filename: /Users/katborski/Documents/GitHub/AFPSC/TESS/tess2021232031932-s0042-0000000250081915-0213-a_fast-lc.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      44   ()
#   1  LIGHTCURVE    1 BinTableHDU    167   110055R x 20C   [D, E, J, E, E, E, E, E, E, J, D, E, D, E, D, E, D, E, E, E]
#   2  APERTURE      1 ImageHDU        49   (11, 11)   int32

# %%
#Read file using Lightkurve
lc = lk.read(file)

# %%
data1.filename()
lc.plot()
# Out:
# <AxesSubplot:xlabel='Time - 2457000 [BTJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %%
#Plot SAP and PDCSAP flux v time
with fits.open(file, mode="readonly") as hdulist:
    tess_bjds = hdulist[1].data['TIME']
    sap_fluxes = hdulist[1].data['SAP_FLUX']
    pdcsap_fluxes = hdulist[1].data['PDCSAP_FLUX']

plt.figure(figsize = (16,4))    
plt.plot(tess_bjds, sap_fluxes)
plt.plot(tess_bjds, pdcsap_fluxes)
plt.show()

# %%
#t= Table.read(file)

# %%
#print(t)

# %%
#print(t.columns)

# %%
#PDCSAP flux v time for 1st file
#plt.figure(figsize=(16,4))
#plt.plot(t['TIME'],t['PDCSAP_FLUX'])
#plt.show()

# %%
#SAP flux v time for 1st file
#plt.figure(figsize=(16,4))
#plt.plot(t['TIME'],t['SAP_FLUX'])
#plt.show()

# %%
#Open 2nd file
file2 = '/Users/katborski/Documents/GitHub/AFPSC/TESS/tess2021232031932-s0042-0000000250081915-0213-s_lc.fits'
fits.info(file2)
# Out:
# Filename: /Users/katborski/Documents/GitHub/AFPSC/TESS/tess2021232031932-s0042-0000000250081915-0213-s_lc.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      44   ()
#   1  LIGHTCURVE    1 BinTableHDU    167   18342R x 20C   [D, E, J, E, E, E, E, E, E, J, D, E, D, E, D, E, D, E, E, E]
#   2  APERTURE      1 ImageHDU        49   (11, 11)   int32

# %%
#Display columns of data for 2nd file, just trying different ways to read data
fits.getdata(file2, ext=1).columns
# Out:
# ColDefs(
#     name = 'TIME'; format = 'D'; unit = 'BJD - 2457000, days'; disp = 'D14.7'
#     name = 'TIMECORR'; format = 'E'; unit = 'd'; disp = 'E14.7'
#     name = 'CADENCENO'; format = 'J'; disp = 'I10'
#     name = 'SAP_FLUX'; format = 'E'; unit = 'e-/s'; disp = 'E14.7'
#     name = 'SAP_FLUX_ERR'; format = 'E'; unit = 'e-/s'; disp = 'E14.7'
#     name = 'SAP_BKG'; format = 'E'; unit = 'e-/s'; disp = 'E14.7'
#     name = 'SAP_BKG_ERR'; format = 'E'; unit = 'e-/s'; disp = 'E14.7'
#     name = 'PDCSAP_FLUX'; format = 'E'; unit = 'e-/s'; disp = 'E14.7'
#     name = 'PDCSAP_FLUX_ERR'; format = 'E'; unit = 'e-/s'; disp = 'E14.7'
#     name = 'QUALITY'; format = 'J'; disp = 'B16.16'
#     name = 'PSF_CENTR1'; format = 'D'; unit = 'pixel'; disp = 'F10.5'
#     name = 'PSF_CENTR1_ERR'; format = 'E'; unit = 'pixel'; disp = 'E14.7'
#     name = 'PSF_CENTR2'; format = 'D'; unit = 'pixel'; disp = 'F10.5'
#     name = 'PSF_CENTR2_ERR'; format = 'E'; unit = 'pixel'; disp = 'E14.7'
# ...

# %%
lc2 = lk.read(file2)
lc2.plot()
# Out:
# <AxesSubplot:xlabel='Time - 2457000 [BTJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %%
#Name variables
with fits.open(data_file, mode="readonly") as hdulist:
    tess_bjds2 = hdulist[1].data['TIME']
    sap_fluxes2 = hdulist[1].data['SAP_FLUX']
    pdcsap_fluxes2 = hdulist[1].data['PDCSAP_FLUX']

# %%
plt.figure(figsize = (16,4))
plt.plot(tess_bjds2, pdcsap_fluxes2)
plt.plot(tess_bjds2, sap_fluxes2)
plt.show()

# %%
plt.figure(figsize = (16,4))
plt.plot(tess_bjds2, pdcsap_fluxes2)
plt.show()

# %%
plt.figure(figsize = (16,4))
plt.plot(tess_bjds2, sap_fluxes2)
plt.show()

# %%
#Open 3rd file
file3 = '/Users/katborski/Documents/GitHub/AFPSC/TESS/tess2021233042500-s0042-s0042-0000000250081915-00517_dvt.fits'
data3 = astropy.io.fits.open(file3)

# %%
data3.info()
# Out:
# Filename: /Users/katborski/Documents/GitHub/AFPSC/TESS/tess2021233042500-s0042-s0042-0000000250081915-00517_dvt.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      43   ()
#   1  TCE_1         1 BinTableHDU     92   18342R x 10C   [D, E, J, E, E, E, E, E, E, E]
#   2  TCE_2         1 BinTableHDU     92   18342R x 10C   [D, E, J, E, E, E, E, E, E, E]
#   3  Statistics    1 BinTableHDU    157   18342R x 38C   [D, E, J, E, E, E, E, J, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E, E]

# %%
#lc3 = lk.read(file3)
#lc3.plot()
# Out:
# ---------------------------------------------------------------------------
# LightkurveError                           Traceback (most recent call last)
# Input In [50], in <cell line: 1>()
# ----> 1 lc3 = lk.read(file3)
#       2 lc3.plot()
#
# File ~/opt/anaconda3/envs/tess_swift_afpsc/lib/python3.9/site-packages/lightkurve/io/read.py:119, in read(path_or_url, **kwargs)
#     114         raise LightkurveError(
#     115             f"{filetype} files are not supported " "in this version of Lightkurve."
#     116         ) from exc
#     117 else:
#     118     # if these keywords don't exist, raise `ValueError`
# --> 119     raise LightkurveError(
#     120         "Not recognized as a supported data product:\n"
#     121         f"{path_or_url}\n"
#     122         "This file may be corrupt due to an interrupted download. "
#     123         "Please remove it from your disk and try again."
#     124     )
#
# LightkurveError: Not recognized as a supported data product:
# ...

# %%
q = Table.read(file3, hdu=3)

# %%
print(q.columns)
# Out:
# <TableColumns names=('TIME','TIMECORR','CADENCENO','PDCSAP_FLUX','PDCSAP_FLUX_ERR','RESIDUAL_LC','DEWEIGHTS','QUALITY','SES_CORR_0_5','SES_CORR_1_0','SES_CORR_1_5','SES_CORR_2_0','SES_CORR_2_5','SES_CORR_3_0','SES_CORR_3_5','SES_CORR_4_5','SES_CORR_5_0','SES_CORR_6_0','SES_CORR_7_5','SES_CORR_9_0','SES_CORR_10_5','SES_CORR_12_5','SES_CORR_15_0','SES_NORM_0_5','SES_NORM_1_0','SES_NORM_1_5','SES_NORM_2_0','SES_NORM_2_5','SES_NORM_3_0','SES_NORM_3_5','SES_NORM_4_5','SES_NORM_5_0','SES_NORM_6_0','SES_NORM_7_5','SES_NORM_9_0','SES_NORM_10_5','SES_NORM_12_5','SES_NORM_15_0')>

# %%
plt.figure(figsize = (16,4))
plt.plot(q['TIME'], q['PDCSAP_FLUX'])
plt.show()

# %%
#Open 4th file
file4 = '/Users/katborski/Documents/GitHub/AFPSC/TESS/tess2021232031932-s0042-0000000250081915-0213-s_tp.fits'
data4 = astropy.io.fits.open(file4)

# %%
file4
# Out:
# '/Users/katborski/Documents/GitHub/AFPSC/TESS/tess2021232031932-s0042-0000000250081915-0213-s_tp.fits'

# %%
lc4 = lk.read(file4)
lc4.plot()
# Out:
# <AxesSubplot:title={'center':'Target ID: 250081915, Cadence: 878570'}, xlabel='Pixel Column Number', ylabel='Pixel Row Number'>

# %%
fits.info(file4)
# Out:
# Filename: /Users/katborski/Documents/GitHub/AFPSC/TESS/tess2021232031932-s0042-0000000250081915-0213-s_tp.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      44   ()
#   1  PIXELS        1 BinTableHDU    248   18342R x 11C   [D, E, J, 121J, 121E, 121E, 121E, 121E, J, E, E]
#   2  APERTURE      1 ImageHDU        49   (11, 11)   int32
#   3  TARGET COSMIC RAY    1 BinTableHDU     27   0R x 4C   [J, I, I, E]

# %%
fits.getdata(file4, ext=1).columns
# Out:
# ColDefs(
#     name = 'TIME'; format = 'D'; unit = 'BJD - 2457000, days'; disp = 'D14.7'
#     name = 'TIMECORR'; format = 'E'; unit = 'd'; disp = 'E14.7'
#     name = 'CADENCENO'; format = 'J'; disp = 'I10'
#     name = 'RAW_CNTS'; format = '121J'; unit = 'count'; null = -1; disp = 'I8'; dim = '(11,11)'
#     name = 'FLUX'; format = '121E'; unit = 'e-/s'; disp = 'E14.7'; dim = '(11,11)'
#     name = 'FLUX_ERR'; format = '121E'; unit = 'e-/s'; disp = 'E14.7'; dim = '(11,11)'
#     name = 'FLUX_BKG'; format = '121E'; unit = 'e-/s'; disp = 'E14.7'; dim = '(11,11)'
#     name = 'FLUX_BKG_ERR'; format = '121E'; unit = 'e-/s'; disp = 'E14.7'; dim = '(11,11)'
#     name = 'QUALITY'; format = 'J'; disp = 'B16.16'
#     name = 'POS_CORR1'; format = 'E'; unit = 'pixel'; disp = 'E14.7'
#     name = 'POS_CORR2'; format = 'E'; unit = 'pixel'; disp = 'E14.7'
# )

# %%
#with fits.open(file4, mode="readonly") as hdulist:
#    tess_bjds4 = hdulist[1].data['TIME']
#    raw_counts4 = hdulist[1].data['RAW_CNTS']
#    calibrated_fluxes4 = hdulist[1].data['FLUX']

# %%
#print(type(calibrated_fluxes4))
#print(calibrated_fluxes4.shape)
# Out:
# <class 'numpy.ndarray'>
# (18342, 11, 11)

# %%
#file 5
file5 = '/Users/katborski/Documents/GitHub/AFPSC/TESS/tess2021232031932-s0042-0000000250081915-0213-a_fast-tp.fits'
data5 = astropy.io.fits.open(file5)

# %%
data5.info()
# Out:
# Filename: /Users/katborski/Documents/GitHub/AFPSC/TESS/tess2021232031932-s0042-0000000250081915-0213-a_fast-tp.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      44   ()
#   1  PIXELS        1 BinTableHDU    248   110055R x 11C   [D, E, J, 121J, 121E, 121E, 121E, 121E, J, E, E]
#   2  APERTURE      1 ImageHDU        49   (11, 11)   int32
#   3  TARGET COSMIC RAY    1 BinTableHDU     27   47787R x 4C   [J, I, I, E]

# %%
r = Table.read(file5, hdu = 1)

# %%
print(r.columns)
# Out:
# <TableColumns names=('TIME','TIMECORR','CADENCENO','RAW_CNTS','FLUX','FLUX_ERR','FLUX_BKG','FLUX_BKG_ERR','QUALITY','POS_CORR1','POS_CORR2')>

# %%
lc5 = lk.read(file5)
lc5.plot()
# Out:
# <AxesSubplot:title={'center':'Target ID: 250081915, Cadence: 5271420'}, xlabel='Pixel Column Number', ylabel='Pixel Row Number'>

# %%
#with fits.open(file5, mode="readonly") as hdulist:
#    tess_bjds5 = hdulist[1].data['TIME']
#    raw_counts5 = hdulist[1].data['RAW_CNTS']
#    calibrated_fluxes5 = hdulist[1].data['FLUX']

# %%
#print(type(calibrated_fluxes5))
#print(calibrated_fluxes5.shape)

# %%
# Start figure and axis.
#fig, ax = plt.subplots()

# Display the calibrated fluxes
#cax = ax.imshow(calibrated_fluxes5[1,:,:], cmap=plt.cm.YlGnBu_r, origin="lower")
